# %%
import pandas as pd
import matplotlib as mp
Q3 = pd.read_excel(r"C:\Users\Pranjal Singh\Downloads\Combined.xlsx", sheet_name='Hillsborough')

#I tried importing the files using just the name and extension but it was not allowing me to do so hece I fetched the files using their Location address.

# %%
Q3.columns = ['Date', 'Daily Number', 'Moving Average']
axes = h_df.plot('Date','Daily Number', color='Red')
Q3.plot('Date', 'Moving Average', kind='bar',xticks=[], color='Black', width=1, ax=axes)
# Out:
# <AxesSubplot:xlabel='Date'>
