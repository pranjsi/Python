# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\Pranjal Singh\Downloads\2018 Data.xlsx")
#I tried importing the files using just the name and extension but it was not allowing me to do so hece I fetched the files using their Location address.

# %%
df
# Out:
#                     NAME  Unemployment Rate  Median Family Income  \
# 0                Alabama                5.6                 63837
# 1                 Alaska                6.8                 89847
# 2                Arizona                5.4                 69981
# 3               Arkansas                4.5                 58080
# 4             California                5.5                 86165
# 5               Colorado                3.9                 88955
# 6            Connecticut                5.5                 98100
# 7               Delaware                5.7                 79386
# 8   District of Columbia                7.5                117713
# 9                Florida                5.2                 66995
# 10               Georgia                4.8                 71457
# 11                Hawaii                3.8                 95448
# 12                 Idaho                4.0                 65987
# ...

# %%
import matplotlib.pyplot as mp

# %%
#Regaular scatter plot with default settings

df.plot('Median Family Income','Perc with health Insurance', kind='scatter')
# Out:
# <AxesSubplot:xlabel='Median Family Income', ylabel='Perc with health Insurance'>

# %%
# Changing the circles to crosses and coloring it to red.

df.plot('Median Family Income','Perc with health Insurance', kind='scatter',c='red',marker='*')
# Out:
# <AxesSubplot:xlabel='Median Family Income', ylabel='Perc with health Insurance'>
